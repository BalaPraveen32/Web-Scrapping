# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = "https://www.flipkart.com/audio-video/headphones/pr?sid=0pm%2Cfcn&otracker=categorytree&p%5B%5D=facets.connectivity%255B%255D%3DBluetooth&fm=neo%2Fmerchandising&iid=M_c3717098-01a1-4b60-9d0f-d6ff660bc0bc_1_372UD5BXDFYS_MC.R08R6GB1Q1BI&otracker=hp_rich_navigation_2_1.navigationCard.RICH_NAVIGATION_Electronics~Audio~Bluetooth%2BHeadphones_R08R6GB1Q1BI&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L2_view-all&cid=R08R6GB1Q1BI"

# %%
allow = requests.get (url)

# %%
print (allow)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup (allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
product_name = soup.select(".s1Q9rs")

# %%
product_title = []
product_link = []

# %%
for item in product_name:
    product_title.append (item.text)
    link = "https://www.flipkart.com"
    product_link.append(link)

# %%
product_title
# Out:
# ['JBL Tune 230NC with Active Noise Cancellation,40Hr Play...',
#  'truke Buds S2 with 48H Playtime, Quad Mic ENC, Instant ...',
#  'Aroma NB119B Badshah - 40 Hours Playtime Bluetooth Neck...',
#  'OnePlus Bullets Wireless Z2 with Fast Charge, 30 Hrs Ba...',
#  'TECHFIRE Fire 500v2 Neckband hi-bass Wireless Bluetooth...',
#  'Grostar TWS Twins Wireless Bluetooth Earphone with Mic ...',
#  'truke Buds F1 with 38H Playtime, Dual Mic ENC, Instant ...',
#  'Wings Phantom 205 Neck band with touch controls Bluetoo...',
#  'Grostar Earbuds In-ear Sensor Bluetooth Touch Control H...',
#  'Aroma NB119 Titanium - 48 Hours Playtime Bluetooth Neck...',
#  'TECHFIRE Fire 500v2 Neckband hi-bass Wireless Bluetooth...',
#  'truke BTG1 Gaming earbuds with 60ms Low Latency | 13mm ...',
#  'Aroma NB119 Titanium - 48 Hours Playtime Bluetooth Neck...',
#  'boAt Airdopes 161 with 17 Hours Battery and Fast Charge...',
#  'OnePlus Bullets Wireless Z2 Bluetooth Headset',
# ...

# %%
product_rate = soup.select("._30jeq3")

# %%
product_cost = []

# %%
for item in product_rate:
    product_cost.append(item.text)

# %%
product_cost
# Out:
# ['₹5,999',
#  '₹1,699',
#  '₹379',
#  '₹1,999',
#  '₹399',
#  '₹318',
#  '₹1,299',
#  '₹1,493',
#  '₹499',
#  '₹499',
#  '₹399',
#  '₹1,999',
#  '₹499',
#  '₹1,399',
#  '₹1,999',
#  '₹999',
#  '₹499',
#  '₹392',
#  '₹1,599',
#  '₹349',
#  '₹369',
#  '₹499',
#  '₹1,499',
#  '₹1,199',
#  '₹1,499',
#  '₹1,199',
#  '₹1,999',
#  '₹1,299',
#  '₹1,599',
#  '₹1,299',
#  '₹449',
#  '₹1,199',
#  '₹1,299',
#  '₹329',
#  '₹499',
#  '₹449',
#  '₹1,599',
#  '₹1,499',
#  '₹419',
#  '₹1,290']

# %%
import pandas as pd

# %%
product = pd.DataFrame(product_title,columns=["Name"])

# %%
product['cost']= product_cost

# %%
product
# Out:
#                                                  Name    cost
# 0   JBL Tune 230NC with Active Noise Cancellation,...  ₹5,999
# 1   truke Buds S2 with 48H Playtime, Quad Mic ENC,...  ₹1,699
# 2   Aroma NB119B Badshah - 40 Hours Playtime Bluet...    ₹379
# 3   OnePlus Bullets Wireless Z2 with Fast Charge, ...  ₹1,999
# 4   TECHFIRE Fire 500v2 Neckband hi-bass Wireless ...    ₹399
# 5   Grostar TWS Twins Wireless Bluetooth Earphone ...    ₹318
# 6   truke Buds F1 with 38H Playtime, Dual Mic ENC,...  ₹1,299
# 7   Wings Phantom 205 Neck band with touch control...  ₹1,493
# 8   Grostar Earbuds In-ear Sensor Bluetooth Touch ...    ₹499
# 9   Aroma NB119 Titanium - 48 Hours Playtime Bluet...    ₹499
# 10  TECHFIRE Fire 500v2 Neckband hi-bass Wireless ...    ₹399
# 11  truke BTG1 Gaming earbuds with 60ms Low Latenc...  ₹1,999
# 12  Aroma NB119 Titanium - 48 Hours Playtime Bluet...    ₹499
# 13  boAt Airdopes 161 with 17 Hours Battery and Fa...  ₹1,399
# ...

# %%
product.to_csv('Product.csv')
